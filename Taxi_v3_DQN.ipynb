# %% [markdown]
# <a href="https://colab.research.google.com/github/albertocj1/Taxi-v3-Reinforcement-Learning/blob/main/Taxi_v3_DQN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gymnasium torch numpy matplotlib imageio[ffmpeg] --quiet

# %%
import random
import numpy as np
import gymnasium as gym
import torch
import torch.nn as nn
import torch.optim as optim
from collections import deque
import matplotlib.pyplot as plt
import imageio
from IPython.display import Video


# Select GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cpu

# %%
import gymnasium as gym

# Create the Taxi-v3 environment
env = gym.make("Taxi-v3")

# Print the observation space
print("Observation Space:", env.observation_space)

# Print the action space
print("Action Space:", env.action_space)

# Close the environment
env.close()
# Out:
# Observation Space: Discrete(500)
# Action Space: Discrete(6)

# %%
class DQN(nn.Module):
    def __init__(self, n_observations, n_actions):
        super(DQN, self).__init__()
        self.layer1 = nn.Linear(n_observations, 80)
        self.relu = nn.ReLU()
        self.layer2 = nn.Linear(80, 80)
        self.output_layer = nn.Linear(80, n_actions)

    def forward(self, x):
        x = self.relu(self.layer1(x))
        x = self.relu(self.layer2(x))
        return self.output_layer(x)

# Get the number of observations and actions from the environment
n_observations = env.observation_space.n
n_actions = env.action_space.n

# Instantiate the DQN model
policy_net = DQN(n_observations, n_actions).to(device)
target_net = DQN(n_observations, n_actions).to(device)
target_net.load_state_dict(policy_net.state_dict())
# Out:
# <All keys matched successfully>

# %%
from collections import deque
import random
import torch
import numpy as np


class ReplayBuffer:
    def __init__(self, capacity=5000):
        self.buffer = deque(maxlen=capacity)

    def push(self, state, action, reward, next_state, done):
        self.buffer.append((state, action, reward, next_state, done))

    def sample(self, batch_size):
        batch = random.sample(self.buffer, batch_size)
        states, actions, rewards, next_states, dones = zip(*batch)
        return (
            torch.FloatTensor(states),
            torch.LongTensor(actions),
            torch.FloatTensor(rewards),
            torch.FloatTensor(next_states),
            torch.FloatTensor(dones),
        )

    def __len__(self):
        return len(self.buffer)

# %%
def train_dqn(episodes,
              gamma,
              lr,
              batch_size,
              epsilon_decay,
              min_epsilon):

    env = gym.make("Taxi-v3")
    n_observations = env.observation_space.n
    n_actions = env.action_space.n

    policy_net = DQN(n_observations, n_actions).to(device)
    target_net = DQN(n_observations, n_actions).to(device)
    target_net.load_state_dict(policy_net.state_dict())
    optimizer = optim.Adam(policy_net.parameters(), lr=lr)
    criterion = nn.MSELoss()

    memory = ReplayBuffer(5000)
    epsilon = 1.0
    rewards_history = []

    for ep in range(episodes):
        state, _ = env.reset()
        done = False
        total_reward = 0

        while not done:
            # ε-greedy policy
            if random.random() < epsilon:
                action = env.action_space.sample()
            else:
                # Convert state to one-hot encoding for network input
                state_one_hot = torch.zeros(n_observations, dtype=torch.float32).to(device)
                state_one_hot[state] = 1.0
                state_tensor = state_one_hot.unsqueeze(0)

                with torch.no_grad():
                    action = torch.argmax(policy_net(state_tensor)).item()

            next_state, reward, terminated, truncated, _ = env.step(action)
            done = terminated or truncated

            memory.push(state, action, reward, next_state, done)
            state = next_state
            total_reward += reward

            # Train network
            if len(memory) >= batch_size:
                states, actions, rewards, next_states, dones = memory.sample(batch_size)

                # 🔹 Move tensors to GPU/CPU device and ensure correct shape
                # Convert states and next_states to one-hot encoding for batch processing
                states_one_hot = torch.zeros(batch_size, n_observations, dtype=torch.float32).to(device)
                states_one_hot[torch.arange(batch_size), states.long()] = 1.0

                next_states_one_hot = torch.zeros(batch_size, n_observations, dtype=torch.float32).to(device)
                next_states_one_hot[torch.arange(batch_size), next_states.long()] = 1.0

                actions = actions.to(device)
                rewards = rewards.to(device)
                dones = dones.to(device)


                q_values = policy_net(states_one_hot).gather(1, actions.unsqueeze(1)).squeeze()
                next_q_values = target_net(next_states_one_hot).max(1)[0]
                expected_q_values = rewards + gamma * next_q_values * (1 - dones)

                loss = criterion(q_values, expected_q_values.detach())

                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

        # Epsilon decay
        epsilon = max(min_epsilon, epsilon * epsilon_decay)
        rewards_history.append(total_reward)

        # Update target network
        if ep % 10 == 0: # Update target network every 10 episodes
             target_net.load_state_dict(policy_net.state_dict())


        print(f"Episode {ep+1}/{episodes}, Total Reward: {total_reward}, Epsilon: {epsilon:.2f}")

    env.close()
    return rewards_history, policy_net

# %%
# Example hyperparameters
episodes = 2000
gamma = 0.99
lr = 0.001
batch_size = 64
epsilon_decay = 0.995
min_epsilon = 0.01

# Train the DQN agent
rewards, trained_policy_net = train_dqn(episodes, gamma, lr, batch_size, epsilon_decay, min_epsilon)
# Out:
# Episode 1/2000, Total Reward: -713, Epsilon: 0.99
# Episode 2/2000, Total Reward: -767, Epsilon: 0.99
# Episode 3/2000, Total Reward: -830, Epsilon: 0.99
# Episode 4/2000, Total Reward: -731, Epsilon: 0.98
# Episode 5/2000, Total Reward: -722, Epsilon: 0.98
# Episode 6/2000, Total Reward: -657, Epsilon: 0.97
# Episode 7/2000, Total Reward: -749, Epsilon: 0.97
# Episode 8/2000, Total Reward: -794, Epsilon: 0.96
# Episode 9/2000, Total Reward: -695, Epsilon: 0.96
# Episode 10/2000, Total Reward: -803, Epsilon: 0.95
# Episode 11/2000, Total Reward: -722, Epsilon: 0.95
# Episode 12/2000, Total Reward: -749, Epsilon: 0.94
# Episode 13/2000, Total Reward: -722, Epsilon: 0.94
# Episode 14/2000, Total Reward: -848, Epsilon: 0.93
# Episode 15/2000, Total Reward: -794, Epsilon: 0.93
# Episode 16/2000, Total Reward: -713, Epsilon: 0.92
# Episode 17/2000, Total Reward: -758, Epsilon: 0.92
# Episode 18/2000, Total Reward: -668, Epsilon: 0.91
# Episode 19/2000, Total Reward: -740, Epsilon: 0.91
# Episode 20/2000, Total Reward: -767, Epsilon: 0.90
# Episode 21/2000, Total Reward: -668, Epsilon: 0.90
# Episode 22/2000, Total Reward: -767, Epsilon: 0.90
# Episode 23/2000, Total Reward: -650, Epsilon: 0.89
# Episode 24/2000, Total Reward: -776, Epsilon: 0.89
# Episode 25/2000, Total Reward: -623, Epsilon: 0.88
# Episode 26/2000, Total Reward: -821, Epsilon: 0.88
# Episode 27/2000, Total Reward: -632, Epsilon: 0.87
# Episode 28/2000, Total Reward: -641, Epsilon: 0.87
# Episode 29/2000, Total Reward: -713, Epsilon: 0.86
# Episode 30/2000, Total Reward: -704, Epsilon: 0.86
# Episode 31/2000, Total Reward: -285, Epsilon: 0.86
# Episode 32/2000, Total Reward: -776, Epsilon: 0.85
# Episode 33/2000, Total Reward: -794, Epsilon: 0.85
# Episode 34/2000, Total Reward: -713, Epsilon: 0.84
# Episode 35/2000, Total Reward: -749, Epsilon: 0.84
# Episode 36/2000, Total Reward: -704, Epsilon: 0.83
# Episode 37/2000, Total Reward: -677, Epsilon: 0.83
# Episode 38/2000, Total Reward: -623, Epsilon: 0.83
# Episode 39/2000, Total Reward: -596, Epsilon: 0.82
# Episode 40/2000, Total Reward: -650, Epsilon: 0.82
# Episode 41/2000, Total Reward: -605, Epsilon: 0.81
# Episode 616/2000, Total Reward: 6, Epsilon: 0.05
# Episode 617/2000, Total Reward: 8, Epsilon: 0.05
# Episode 618/2000, Total Reward: 6, Epsilon: 0.05
# Episode 619/2000, Total Reward: -7, Epsilon: 0.04
# Episode 620/2000, Total Reward: 5, Epsilon: 0.04
# Episode 621/2000, Total Reward: -4, Epsilon: 0.04
# Episode 622/2000, Total Reward: -2, Epsilon: 0.04
# Episode 623/2000, Total Reward: 6, Epsilon: 0.04
# Episode 624/2000, Total Reward: 3, Epsilon: 0.04
# Episode 625/2000, Total Reward: 8, Epsilon: 0.04
# Episode 626/2000, Total Reward: 14, Epsilon: 0.04
# Episode 627/2000, Total Reward: 6, Epsilon: 0.04
# Episode 628/2000, Total Reward: 3, Epsilon: 0.04
# Episode 629/2000, Total Reward: 3, Epsilon: 0.04
# Episode 630/2000, Total Reward: 9, Epsilon: 0.04
# Episode 631/2000, Total Reward: 3, Epsilon: 0.04
# Episode 632/2000, Total Reward: 8, Epsilon: 0.04
# Episode 633/2000, Total Reward: 6, Epsilon: 0.04
# Episode 634/2000, Total Reward: -5, Epsilon: 0.04
# Episode 635/2000, Total Reward: 11, Epsilon: 0.04
# Episode 636/2000, Total Reward: 14, Epsilon: 0.04
# Episode 637/2000, Total Reward: 10, Epsilon: 0.04
# Episode 638/2000, Total Reward: 8, Epsilon: 0.04
# Episode 639/2000, Total Reward: 11, Epsilon: 0.04
# Episode 640/2000, Total Reward: 5, Epsilon: 0.04
# Episode 641/2000, Total Reward: 7, Epsilon: 0.04
# Episode 642/2000, Total Reward: -12, Epsilon: 0.04
# Episode 643/2000, Total Reward: 7, Epsilon: 0.04
# Episode 644/2000, Total Reward: -3, Epsilon: 0.04
# Episode 645/2000, Total Reward: 7, Epsilon: 0.04
# Episode 646/2000, Total Reward: 13, Epsilon: 0.04
# Episode 647/2000, Total Reward: -7, Epsilon: 0.04
# Episode 648/2000, Total Reward: 4, Epsilon: 0.04
# Episode 649/2000, Total Reward: 11, Epsilon: 0.04
# Episode 650/2000, Total Reward: 5, Epsilon: 0.04
# Episode 651/2000, Total Reward: 10, Epsilon: 0.04
# Episode 652/2000, Total Reward: 13, Epsilon: 0.04
# Episode 653/2000, Total Reward: 6, Epsilon: 0.04
# Episode 654/2000, Total Reward: 7, Epsilon: 0.04
# Episode 655/2000, Total Reward: -5, Epsilon: 0.04
# Episode 656/2000, Total Reward: 8, Epsilon: 0.04
# Episode 657/2000, Total Reward: 11, Epsilon: 0.04
# Episode 658/2000, Total Reward: -4, Epsilon: 0.04
# Episode 659/2000, Total Reward: 6, Epsilon: 0.04
# Episode 660/2000, Total Reward: 7, Epsilon: 0.04
# Episode 661/2000, Total Reward: 6, Epsilon: 0.04
# Episode 662/2000, Total Reward: 7, Epsilon: 0.04
# Episode 663/2000, Total Reward: 6, Epsilon: 0.04
# Episode 664/2000, Total Reward: -15, Epsilon: 0.04
# Episode 665/2000, Total Reward: 10, Epsilon: 0.04
# Episode 666/2000, Total Reward: 7, Epsilon: 0.04
# Episode 667/2000, Total Reward: 7, Epsilon: 0.04
# Episode 668/2000, Total Reward: 5, Epsilon: 0.04
# Episode 669/2000, Total Reward: 8, Epsilon: 0.03
# Episode 670/2000, Total Reward: 15, Epsilon: 0.03
# Episode 671/2000, Total Reward: 7, Epsilon: 0.03
# Episode 672/2000, Total Reward: 7, Epsilon: 0.03
# Episode 673/2000, Total Reward: 6, Epsilon: 0.03
# Episode 674/2000, Total Reward: -41, Epsilon: 0.03
# Episode 675/2000, Total Reward: 7, Epsilon: 0.03
# Episode 676/2000, Total Reward: 12, Epsilon: 0.03
# Episode 677/2000, Total Reward: 7, Epsilon: 0.03
# Episode 678/2000, Total Reward: 7, Epsilon: 0.03
# Episode 679/2000, Total Reward: 14, Epsilon: 0.03
# Episode 680/2000, Total Reward: 9, Epsilon: 0.03
# Episode 681/2000, Total Reward: -14, Epsilon: 0.03
# Episode 682/2000, Total Reward: -3, Epsilon: 0.03
# Episode 683/2000, Total Reward: -3, Epsilon: 0.03
# Episode 684/2000, Total Reward: 9, Epsilon: 0.03
# Episode 685/2000, Total Reward: 6, Epsilon: 0.03
# Episode 686/2000, Total Reward: 9, Epsilon: 0.03
# Episode 687/2000, Total Reward: 5, Epsilon: 0.03
# Episode 688/2000, Total Reward: -15, Epsilon: 0.03
# Episode 689/2000, Total Reward: -2, Epsilon: 0.03
# Episode 690/2000, Total Reward: 1, Epsilon: 0.03
# Episode 691/2000, Total Reward: 6, Epsilon: 0.03
# Episode 692/2000, Total Reward: 7, Epsilon: 0.03
# Episode 693/2000, Total Reward: 9, Epsilon: 0.03
# Episode 694/2000, Total Reward: 7, Epsilon: 0.03
# Episode 695/2000, Total Reward: 6, Epsilon: 0.03
# Episode 696/2000, Total Reward: 2, Epsilon: 0.03
# Episode 697/2000, Total Reward: 8, Epsilon: 0.03
# Episode 698/2000, Total Reward: 10, Epsilon: 0.03
# Episode 699/2000, Total Reward: -2, Epsilon: 0.03
# Episode 700/2000, Total Reward: 11, Epsilon: 0.03
# Episode 701/2000, Total Reward: 7, Epsilon: 0.03
# Episode 702/2000, Total Reward: -4, Epsilon: 0.03
# Episode 703/2000, Total Reward: -3, Epsilon: 0.03
# Episode 704/2000, Total Reward: 14, Epsilon: 0.03
# Episode 705/2000, Total Reward: 2, Epsilon: 0.03
# Episode 706/2000, Total Reward: 1, Epsilon: 0.03
# Episode 707/2000, Total Reward: -2, Epsilon: 0.03
# Episode 708/2000, Total Reward: -4, Epsilon: 0.03
# Episode 709/2000, Total Reward: 9, Epsilon: 0.03
# Episode 710/2000, Total Reward: 6, Epsilon: 0.03
# Episode 711/2000, Total Reward: 9, Epsilon: 0.03
# Episode 712/2000, Total Reward: 11, Epsilon: 0.03
# Episode 713/2000, Total Reward: -8, Epsilon: 0.03
# Episode 714/2000, Total Reward: 5, Epsilon: 0.03
# Episode 715/2000, Total Reward: 8, Epsilon: 0.03
# Episode 716/2000, Total Reward: 9, Epsilon: 0.03
# Episode 717/2000, Total Reward: 8, Epsilon: 0.03
# Episode 718/2000, Total Reward: 6, Epsilon: 0.03
# Episode 719/2000, Total Reward: 5, Epsilon: 0.03
2000, Total Reward: 7, Epsilon: 0.01
# Episode 1954/2000, Total Reward: 8, Epsilon: 0.01
# Episode 1955/2000, Total Reward: 9, Epsilon: 0.01
# Episode 1956/2000, Total Reward: 9, Epsilon: 0.01
# Episode 1957/2000, Total Reward: 6, Epsilon: 0.01
# Episode 1958/2000, Total Reward: 11, Epsilon: 0.01
# Episode 1959/2000, Total Reward: 6, Epsilon: 0.01
# Episode 1960/2000, Total Reward: 2, Epsilon: 0.01
# Episode 1961/2000, Total Reward: 9, Epsilon: 0.01
# Episode 1962/2000, Total Reward: 9, Epsilon: 0.01
# Episode 1963/2000, Total Reward: 4, Epsilon: 0.01
# Episode 1964/2000, Total Reward: 11, Epsilon: 0.01
# Episode 1965/2000, Total Reward: 3, Epsilon: 0.01
# Episode 1966/2000, Total Reward: 6, Epsilon: 0.01
# Episode 1967/2000, Total Reward: 6, Epsilon: 0.01
# Episode 1968/2000, Total Reward: 7, Epsilon: 0.01
# Episode 1969/2000, Total Reward: -6, Epsilon: 0.01
# Episode 1970/2000, Total Reward: 12, Epsilon: 0.01
# Episode 1971/2000, Total Reward: 7, Epsilon: 0.01
# Episode 1972/2000, Total Reward: 11, Epsilon: 0.01
# Episode 1973/2000, Total Reward: 8, Epsilon: 0.01
# Episode 1974/2000, Total Reward: 8, Epsilon: 0.01
# Episode 1975/2000, Total Reward: 8, Epsilon: 0.01
# Episode 1976/2000, Total Reward: 11, Epsilon: 0.01
# Episode 1977/2000, Total Reward: 1, Epsilon: 0.01
# Episode 1978/2000, Total Reward: 8, Epsilon: 0.01
# Episode 1979/2000, Total Reward: 7, Epsilon: 0.01
# Episode 1980/2000, Total Reward: 10, Epsilon: 0.01
# Episode 1981/2000, Total Reward: 5, Epsilon: 0.01
# Episode 1982/2000, Total Reward: 13, Epsilon: 0.01
# Episode 1983/2000, Total Reward: 9, Epsilon: 0.01
# Episode 1984/2000, Total Reward: 8, Epsilon: 0.01
# Episode 1985/2000, Total Reward: 12, Epsilon: 0.01
# Episode 1986/2000, Total Reward: 12, Epsilon: 0.01
# Episode 1987/2000, Total Reward: 9, Epsilon: 0.01
# Episode 1988/2000, Total Reward: 4, Epsilon: 0.01
# Episode 1989/2000, Total Reward: 11, Epsilon: 0.01
# Episode 1990/2000, Total Reward: 6, Epsilon: 0.01
# Episode 1991/2000, Total Reward: 7, Epsilon: 0.01
# Episode 1992/2000, Total Reward: -7, Epsilon: 0.01
# Episode 1993/2000, Total Reward: 8, Epsilon: 0.01
# Episode 1994/2000, Total Reward: 8, Epsilon: 0.01
# Episode 1995/2000, Total Reward: 8, Epsilon: 0.01
# Episode 1996/2000, Total Reward: 8, Epsilon: 0.01
# Episode 1997/2000, Total Reward: 10, Epsilon: 0.01
# Episode 1998/2000, Total Reward: 7, Epsilon: 0.01
# Episode 1999/2000, Total Reward: 9, Epsilon: 0.01
# Episode 2000/2000, Total Reward: 10, Epsilon: 0.01

# %%
# Create the Taxi-v3 environment with render_mode="rgb_array"
env = gym.make("Taxi-v3", render_mode="rgb_array")

# Define the video path and create an imageio writer
video_path = "taxi_dqn.mp4"
writer = imageio.get_writer(video_path, fps=15)

# Run multiple episodes and record the video
episodes_to_record = 20  # Record 10 episodes

for ep in range(episodes_to_record):
    state, _ = env.reset()
    done = False
    while not done:
        # Convert state to one-hot encoding for network input
        state_one_hot = torch.zeros(env.observation_space.n, dtype=torch.float32).to(device)
        state_one_hot[state] = 1.0
        state_tensor = state_one_hot.unsqueeze(0)

        with torch.no_grad():
            action = torch.argmax(trained_policy_net(state_tensor)).item()

        next_state, _, terminated, truncated, _ = env.step(action)
        done = terminated or truncated
        state = next_state

        # Render the environment and append the frame to the video writer
        frame = env.render()
        writer.append_data(frame)

# Close the video writer and the environment
writer.close()
env.close()

print(f"Video saved to {video_path}")

# Display the video
Video(video_path)
# Out:
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (550, 350) to (560, 352) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# Video saved to taxi_dqn.mp4
# <video src="taxi_dqn.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
Video("taxi_dqn.mp4", embed=True)
# Out:
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
def evaluate_agent(env, policy_net, episodes=20):
    total_rewards = []
    for _ in range(episodes):
        state, _ = env.reset()
        done = False
        ep_reward = 0
        while not done:
            # Convert state to one-hot encoding for network input
            state_one_hot = torch.zeros(env.observation_space.n, dtype=torch.float32).to(device)
            state_one_hot[state] = 1.0
            state_tensor = state_one_hot.unsqueeze(0)

            with torch.no_grad():
                action = torch.argmax(policy_net(state_tensor)).item()

            state, reward, terminated, truncated, _ = env.step(action)
            done = terminated or truncated
            ep_reward += reward
        total_rewards.append(ep_reward)
    return np.mean(total_rewards)

# Create the Taxi-v3 environment for evaluation
eval_env = gym.make("Taxi-v3")

# Evaluate the trained agent
avg_reward = evaluate_agent(eval_env, trained_policy_net, episodes=20)
print(f"Average reward over 20 evaluation episodes: {avg_reward:.2f}")

# Close the environment
eval_env.close()
# Out:
# Average reward over 20 evaluation episodes: -2.45
